# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib as plt

# %%
#Importing Breast Cancer Data
column_names = ['Diagnosis', 'radius1', 'texture1', 'perimeter1', 'area1', 'smoothness1', 'compactness1', 'concavity1','concavepoints1','symmetry1','fractal1','radius2', 'texture2', 'perimeter2', 'area2', 'smoothness2', 'compactness2', 'concavity2','concavepoints2','symmetry2','fractal2','radius3', 'texture3', 'perimeter3', 'area3', 'smoothness3', 'compactness3', 'concavity3','concavepoints3','symmetry3','fractal3']
data = pd.read_csv('wdbc.data',names=column_names)
lable = {"B":0, 'M':1}
data['Diagnosis']=data['Diagnosis'].map(lable)

# %%
#Haviing a look at our data set
data.head()
# Out:
#           Diagnosis  radius1  texture1  perimeter1   area1  smoothness1  \
# 842302            1    17.99     10.38      122.80  1001.0      0.11840
# 842517            1    20.57     17.77      132.90  1326.0      0.08474
# 84300903          1    19.69     21.25      130.00  1203.0      0.10960
# 84348301          1    11.42     20.38       77.58   386.1      0.14250
# 84358402          1    20.29     14.34      135.10  1297.0      0.10030
#
#           compactness1  concavity1  concavepoints1  symmetry1  ...  radius3  \
# 842302         0.27760      0.3001         0.14710     0.2419  ...    25.38
# 842517         0.07864      0.0869         0.07017     0.1812  ...    24.99
# 84300903       0.15990      0.1974         0.12790     0.2069  ...    23.57
# 84348301       0.28390      0.2414         0.10520     0.2597  ...    14.91
# 84358402       0.13280      0.1980         0.10430     0.1809  ...    22.54
#
# ...

# %%
#Checking null values 
data.isnull()
# Out:
#         ID  Diagnosis  radius1  texture1  perimeter1  area1  smoothness1  \
# 0    False      False    False     False       False  False        False
# 1    False      False    False     False       False  False        False
# 2    False      False    False     False       False  False        False
# 3    False      False    False     False       False  False        False
# 4    False      False    False     False       False  False        False
# ..     ...        ...      ...       ...         ...    ...          ...
# 564  False      False    False     False       False  False        False
# 565  False      False    False     False       False  False        False
# 566  False      False    False     False       False  False        False
# 567  False      False    False     False       False  False        False
# 568  False      False    False     False       False  False        False
#
#      compactness1  concavity1  concavepoints1  ...  radius3  texture3  \
# ...

# %%
x=data
y=data['Diagnosis']

# %%
#splitting data set into training (80%)and (20%) for testing 
test_split = int(data.shape[0]*0.8)
val_split_idx = int(data.shape[0]*0.8)
test_data = data[test_split:]
val_data = data[val_split_idx:test_split]
data = data[:val_split_idx]
train_Y, train_X = data['Diagnosis'], data.drop('Diagnosis', axis=1)
val_Y, val_X = val_data['Diagnosis'], val_data.drop('Diagnosis', axis=1)
test_Y, test_X = test_data['Diagnosis'], test_data.drop('Diagnosis', axis=1)

# %%
train_X.head()
# Out:
#           radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 842302      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 842517      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 84300903    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 84348301    11.42     20.38       77.58   386.1      0.14250       0.28390
# 84358402    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#           concavity1  concavepoints1  symmetry1  fractal1  ...  radius3  \
# 842302        0.3001         0.14710     0.2419   0.07871  ...    25.38
# 842517        0.0869         0.07017     0.1812   0.05667  ...    24.99
# 84300903      0.1974         0.12790     0.2069   0.05999  ...    23.57
# 84348301      0.2414         0.10520     0.2597   0.09744  ...    14.91
# 84358402      0.1980         0.10430     0.1809   0.05883  ...    22.54
#
#           texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# ...

# %%
train_Y.head()
# Out:
# 842302      1
# 842517      1
# 84300903    1
# 84348301    1
# 84358402    1
# Name: Diagnosis, dtype: int64

# %%
# Data preprocessing
X_train = np.array(train_X)
y_train = np.array(train_Y)
X_test = np.array(test_X)
y_test = np.array(test_Y)

# %% [markdown]
# # Using Newtons Method:

# %%
total=6.4
# Sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
class LogisticRegression:
    
    def __init__(self, learning_rate=0.1, num_iterations=1000, alpha=0.1):
        
        self.learning_rate = learning_rate
        self.num_iterations = num_iterations
        self.alpha = alpha  # L2 regularization parameter

    def fit(self, X, y):
        m, n = X.shape
        self.theta = np.zeros(n)
        
        for i in range(self.num_iterations):
            z = np.dot(X, self.theta)
            h = sigmoid(z)
            gradient = (np.dot(X.T, (h - y)) + 2 * self.alpha * self.theta) / m  
            self.theta -= self.learning_rate * gradient

    def predict(self, X):
        z = np.dot(X, self.theta)
        return (sigmoid(z) >= 0.5).astype(int)

    def accuracy(self, y_true, y_pred):
        return np.mean(y_true == y_pred)

# %%
#train the model
model = LogisticRegression(learning_rate=0.1, num_iterations=1000, alpha=0.1)
model.fit(X_train, y_train)
# Out:
# C:\Users\Mujtaba\anaconda3\envs\mhumayon\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Make predictions on test data
y_pred = model.predict(X_test)
# Out:
# C:\Users\Mujtaba\anaconda3\envs\mhumayon\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
avg_accuracy=0
# Separate features and labels

for i in range(10):
    train_X,test_X,train_Y,test_Y
    accuracy = model.accuracy(y_test,y_pred)
    avg_accuracy+=accuracy

avg_accuracy=avg_accuracy/total
print("======================================")
print(" Avg Accuracy on 10 test_sets: {:.2f}%".format(avg_accuracy * 100))
print("======================================")
# Out:
# ...
#  Avg Accuracy on 10 test_sets: 93.20%
# ...

# %% [markdown]
# # Using Sklearn Logistic Regression:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# spitting the dataset into training and testing portions
X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size=0.2, random_state=42)

# applying Logistic Regression
classifier = LogisticRegression()

# Now Training the Model with training data
classifier.fit(X_train, y_train)

# Now making these predictions on testing data
y_predictions = classifier.predict(X_test)

# Finally evaluating the model and finding the accuracy
f_accuracy = accuracy_score(y_test, y_predictions)
print(f'Accuracy: {accuracy_result:.2f}')

# printing out the whole report of the model
report = classification_report(y_test, y_predictions)
print(report)
# Out:
# Accuracy: 0.96
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        71
#            1       0.98      0.93      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
# C:\Users\Mujtaba\anaconda3\envs\mhumayon\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Finally printing out the Accuracy of the model using logistic regression
from sklearn.metrics import accuracy_score
f_accuracy = accuracy_result*100
print("=========================")
print(f'Accuracy: {f_accuracy:.2f}%')
print("=========================")
# Out:
# ...
# Accuracy: 96.49%
# ...

# %% [markdown]
# ******************END**************************
